# %%
from __future__ import annotations
from pathlib import Path
from typing import Dict, Tuple, List
import os
import json
import pandas as pd
import numpy as np
from loguru import logger

# %%
BASE_DIR = os.getcwd()
HOME_DIR = os.path.dirname(BASE_DIR)
old_data_dates = os.listdir(os.path.join(HOME_DIR, "hl-node-trades"))

# --- Config/paths ---
DATA_DIR = Path(os.path.join(HOME_DIR, "data"))
DATA_DIR.mkdir(parents=True, exist_ok=True)

WALLETS_CSV = DATA_DIR / "wallet_db.csv"

# %%
# --- Wallet DB helpers ---
def load_wallet_db(csv_path: Path = WALLETS_CSV) -> Tuple[Dict[str, int], int]:
    """
    Load wallets from CSV into a dict {wallet: wallet_id}, return dict and next_id.
    If file doesn't exist, start fresh at 1.
    """
    mapping: Dict[str, int] = {}
    next_id = 1
    if csv_path.exists():
        df = pd.read_csv(csv_path, dtype={"wallet_id": "uint32", "wallet": "string"})
        if not df.empty:
            for wid, wal in zip(df["wallet_id"].astype("uint32"), df["wallet"].astype("string")):
                mapping[str(wal)] = int(wid)
            next_id = int(df["wallet_id"].max()) + 1
    else:
        csv_path.parent.mkdir(parents=True, exist_ok=True)
        pd.DataFrame(columns=["wallet_id", "wallet"]).to_csv(csv_path, index=False)
    return mapping, next_id

def append_wallet(csv_path: Path, wallet: str, wallet_id: int) -> None:
    """Append a single wallet row to the CSV."""
    pd.DataFrame([{"wallet_id": wallet_id, "wallet": wallet}]).to_csv(
        csv_path, mode="a", header=False, index=False
    )

def get_wallet_id(wallet: str, mapping: Dict[str, int], next_id_ref: List[int], csv_path: Path) -> int:
    """
    Return wallet_id for wallet, creating a new id if needed.
    next_id_ref is a single-item list to allow in-place increment.
    """
    w = str(wallet)
    wid = mapping.get(w)
    if wid is not None:
        return wid
    wid = next_id_ref[0]
    mapping[w] = wid
    next_id_ref[0] += 1
    append_wallet(csv_path, w, wid)
    return wid

def retrieve_data(file_path: Path, wallet_map: Dict[str, int], next_id_ref: List[int], wallets_csv: Path = WALLETS_CSV) -> pd.DataFrame:
    """
    Read a newline-delimited JSON file of trades and produce a normalized DataFrame
    for later partitioned saving.
    Output columns: coin, price, size, time, is_ask, wallet_id
    """
    records = []
    with open(file_path) as f:
        append = records.append
        for line in f:
            if not line.strip():
                continue
            trade = json.loads(line)

            side_info_list = trade.get("side_info")
            buyer_wallet = side_info_list[0].get("user")
            seller_wallet = side_info_list[1].get("user")
            buyer_wallet_id = get_wallet_id(buyer_wallet, wallet_map, next_id_ref, wallets_csv)
            seller_wallet_id = get_wallet_id(seller_wallet, wallet_map, next_id_ref, wallets_csv)
    
            px = trade.get("px")
            sz = trade.get("sz")

            append(
                {
                    "coin": trade.get("coin"),
                    "price": float(px),
                    "size": float(sz),
                    "time": trade.get("time"),
                    "seller": seller_wallet_id,
                    "buyer": buyer_wallet_id,
                }
            )

    df = pd.DataFrame.from_records(records)
    if df.empty:
        return df

    # Types & cleaning
    df["time"] = pd.to_datetime(df["time"], errors="coerce")
    df = df.dropna(subset=["time"])
    # enforce dtypes
    df["price"] = df["price"].astype("float32")
    df["size"] = df["size"].astype("float32")
    df["seller"] = df["seller"].astype("uint64")
    df["buyer"] = df["buyer"].astype("uint64")

    return df[["coin", "price", "size", "time", "seller", "buyer"]]

def _target_path_for(coin: str, dt: pd.Timestamp) -> Path:
    return DATA_DIR / str(coin) / f"{dt.date()}.parquet"

def _write_daily_parquet(target: Path, df_day: pd.DataFrame) -> None:
    """
    Write/merge the daily file. If target exists, read, concat, de-dup, sort, write.
    We de-dup on [time, wallet_id, price, size, is_ask] as a reasonable row identity.
    """
    target.parent.mkdir(parents=True, exist_ok=True)

    # Keep only required columns & types
    cols = ["price", "size", "time", "seller", "buyer"]
    df_day = df_day[cols].copy()

    if target.exists():
        try:
            old = pd.read_parquet(target, engine="pyarrow")
            # Cast to same dtypes to avoid upcasting surprises
            old["price"] = old["price"].astype("float32")
            old["size"] = old["size"].astype("float32")
            old["time"] = pd.to_datetime(old["time"], errors="coerce")
            old["seller"] = old["seller"].astype("uint64")
            old["buyer"] = old["buyer"].astype("uint64")
            df_day = pd.concat([old, df_day], ignore_index=True)
        except Exception as e:
            logger.warning(f"Failed to read existing parquet {target}: {e}. Overwriting.")

    df_day = df_day.dropna(subset=["time"]).drop_duplicates(
        subset=["time", "seller", "buyer", "price", "size"], keep="last"
    )
    df_day = df_day.sort_values("time")
    df_day.to_parquet(target, index=False, engine="pyarrow", compression="snappy")

def save_partitioned(df: pd.DataFrame) -> None:
    """
    Save rows to data/<coin>/<YYYY-MM-DD>.parquet, merging per-day files if present.
    """
    if df.empty:
        logger.warning("No data to save.")
        return

    # Add date for grouping
    df = df.copy()
    df["date"] = df["time"].dt.date

    # Group by coin/date
    for (coin, day), g in df.groupby(["coin", "date"], sort=False):
        if pd.isna(coin) or coin == "":
            logger.warning("Skipping rows with empty coin.")
            continue
        target = DATA_DIR / str(coin) / f"{day}.parquet"
        _write_daily_parquet(target, g)

    logger.info("Data has been saved successfully.")

# %%
old_data_folders = os.listdir(os.path.join(HOME_DIR, "hl-node-trades"))

wallet_map, next_id = load_wallet_db()
next_id_ref = [next_id]  # mutable holder


for i, date in enumerate(old_data_folders):
    hour_file_names = os.listdir(os.path.join(HOME_DIR, "hl-node-trades", date))

    for file_name in hour_file_names:
        file_full_path = os.path.join(HOME_DIR, "hl-node-trades", date, file_name)

        logger.info(f"{file_full_path} is processing")
        df = retrieve_data(Path(file_full_path), wallet_map, next_id_ref, WALLETS_CSV)
        save_partitioned(df)

    logger.info(f"Processed {i} out of {len(old_data_folders)}")
# Out:
# 2025-10-02 14:12:21.247 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/10.json is processing
# 2025-10-02 14:12:21.832 | INFO     | __main__:save_partitioned:143 - Data has been saved successfully.
# 2025-10-02 14:12:21.834 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/14.json is processing
# 2025-10-02 14:12:23.716 | INFO     | __main__:save_partitioned:143 - Data has been saved successfully.
# 2025-10-02 14:12:23.718 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/12.json is processing
# 2025-10-02 14:12:25.609 | INFO     | __main__:save_partitioned:143 - Data has been saved successfully.
# 2025-10-02 14:12:25.611 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/19.json is processing
# 2025-10-02 14:12:27.261 | INFO     | __main__:save_partitioned:143 - Data has been saved successfully.
# 2025-10-02 14:12:27.263 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/21.json is processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 15
#      13     logger.info(f"{file_full_path} is processing")
#      14     df = retrieve_data(Path(file_full_path), wallet_map, next_id_ref, WALLETS_CSV)
# ---> 15     save_partitioned(df)
#      17 logger.info(f"Processed {i} out of {len(old_data_folders)}")
#
# Cell In[11], line 141, in save_partitioned(df)
#     139         continue
#     140     target = DATA_DIR / str(coin) / f"{day}.parquet"
# --> 141     _write_daily_parquet(target, g)
#     143 logger.info("Data has been saved successfully.")
#
# Cell In[11], line 112, in _write_daily_parquet(target, df_day)
#     110     old["time"] = pd.to_datetime(old["time"], errors="coerce")
#     111     old["seller"] = old["seller"].astype("uint64")
# --> 112     old["buyer"] = old["buyer"].astype("uint64")
#     113     df_day = pd.concat([old, df_day], ignore_index=True)
#     114 except Exception as e:
#
# File ~/jupyter-env/lib/python3.11/site-packages/pandas/core/frame.py:4083, in DataFrame.__getitem__(self, key)
#    4076 # GH#45316 Return view if key is not duplicated
#    4077 # Only use drop_duplicates with duplicates for performance
#    4078 if not is_mi and (
#    4079     self.columns.is_unique
#    4080     and key in self.columns
#    4081     or key in self.columns.drop_duplicates(keep=False)
#    4082 ):
# -> 4083     return self._get_item_cache(key)
#    4085 elif is_mi and self.columns.is_unique and key in self.columns:
#    4086     return self._getitem_multilevel(key)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pandas/core/frame.py:4644, in DataFrame._get_item_cache(self, item)
#    4639 if res is None:
#    4640     # All places that call _get_item_cache have unique columns,
#    4641     #  pending resolution of GH#33047
#    4643     loc = self.columns.get_loc(item)
# -> 4644     res = self._ixs(loc, axis=1)
#    4646     cache[item] = res
#    4648     # for a chain
#
# File ~/jupyter-env/lib/python3.11/site-packages/pandas/core/frame.py:4016, in DataFrame._ixs(self, i, axis)
#    4013 label = self.columns[i]
#    4015 col_mgr = self._mgr.iget(i)
# -> 4016 result = self._box_col_values(col_mgr, i)
#    4018 # this is a cached value, mark it so
#    4019 result._set_as_cached(label, self)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pandas/core/frame.py:4619, in DataFrame._box_col_values(self, values, loc)
#    4614 """
#    4615 Provide boxed values for a column.
#    4616 """
#    4617 # Lookup in columns so that if e.g. a str datetime was passed
#    4618 #  we attach the Timestamp object as the name.
# -> 4619 name = self.columns[loc]
#    4620 # We get index=self.index bc values is a SingleDataManager
#    4621 obj = self._constructor_sliced_from_mgr(values, axes=values.axes)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:5398, in Index.__getitem__(self, key)
#    5386 """
#    5387 Override numpy.ndarray's __getitem__ method to work as desired.
#    5388
#    (...)   5394
#    5395 """
#    5396 getitem = self._data.__getitem__
# -> 5398 if is_integer(key) or is_float(key):
#    5399     # GH#44051 exclude bool, which would return a 2d ndarray
#    5400     key = com.cast_scalar_indexer(key)
#    5401     return getitem(key)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~/jupyter-env/lib/python3.11/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~/jupyter-env/lib/python3.11/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/jupyter-env/lib/python3.11/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~/jupyter-env/lib/python3.11/site-packages/stack_data/utils.py:166, in _pygmented_with_ranges(formatter, code, ranges)
#     164 lexer = MyLexer(stripnl=False)
#     165 try:
# --> 166     highlighted = pygments.highlight(code, lexer, formatter)
#     167 except Exception:
#     168     # When pygments fails, prefer code without highlighting over crashing
#     169     highlighted = code
#
# File ~/jupyter-env/lib/python3.11/site-packages/pygments/__init__.py:82, in highlight(code, lexer, formatter, outfile)
#      77 def highlight(code, lexer, formatter, outfile=None):
#      78     """
#      79     This is the most high-level highlighting function. It combines `lex` and
#      80     `format` in one function.
#      81     """
# ---> 82     return format(lex(code, lexer), formatter, outfile)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pygments/__init__.py:64, in format(tokens, formatter, outfile)
#      62 if not outfile:
#      63     realoutfile = getattr(formatter, 'encoding', None) and BytesIO() or StringIO()
# ---> 64     formatter.format(tokens, realoutfile)
#      65     return realoutfile.getvalue()
#      66 else:
#
# File ~/jupyter-env/lib/python3.11/site-packages/pygments/formatters/terminal256.py:250, in Terminal256Formatter.format(self, tokensource, outfile)
#     249 def format(self, tokensource, outfile):
# --> 250     return Formatter.format(self, tokensource, outfile)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pygments/formatter.py:124, in Formatter.format(self, tokensource, outfile)
#     121 if self.encoding:
#     122     # wrap the outfile in a StreamWriter
#     123     outfile = codecs.lookup(self.encoding)[3](outfile)
# --> 124 return self.format_unencoded(tokensource, outfile)
#
# File ~/jupyter-env/lib/python3.11/site-packages/pygments/formatters/terminal256.py:265, in Terminal256Formatter.format_unencoded(self, tokensource, outfile)
#     261 on, off = self.style_string[str(ttype)]
#     263 # Like TerminalFormatter, add "reset colors" escape sequence
#     264 # on newline.
# --> 265 spl = value.split('\n')
#     266 for line in spl[:-1]:
#     267     if line:
#
# KeyboardInterrupt:
