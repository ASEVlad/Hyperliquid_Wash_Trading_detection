# %%
from __future__ import annotations
from pathlib import Path
from typing import Dict, Tuple, List
import os
import json
import pandas as pd
import numpy as np
from loguru import logger

# %%
BASE_DIR = os.getcwd()
HOME_DIR = os.path.dirname(BASE_DIR)
old_data_dates = os.listdir(os.path.join(HOME_DIR, "hl-node-trades"))

# --- Config/paths ---
DATA_DIR = Path(os.path.join(HOME_DIR, "data"))
DATA_DIR.mkdir(parents=True, exist_ok=True)

WALLETS_CSV = DATA_DIR / "wallet_db.csv"

# %%
# --- Wallet DB helpers ---
def load_wallet_db(csv_path: Path = WALLETS_CSV) -> Tuple[Dict[str, int], int]:
    """
    Load wallets from CSV into a dict {wallet: wallet_id}, return dict and next_id.
    If file doesn't exist, start fresh at 1.
    """
    mapping: Dict[str, int] = {}
    next_id = 1
    if csv_path.exists():
        df = pd.read_csv(csv_path, dtype={"wallet_id": "uint32", "wallet": "string"})
        if not df.empty:
            for wid, wal in zip(df["wallet_id"].astype("uint32"), df["wallet"].astype("string")):
                mapping[str(wal)] = int(wid)
            next_id = int(df["wallet_id"].max()) + 1
    else:
        csv_path.parent.mkdir(parents=True, exist_ok=True)
        pd.DataFrame(columns=["wallet_id", "wallet"]).to_csv(csv_path, index=False)
    return mapping, next_id

def append_wallet(csv_path: Path, wallet: str, wallet_id: int) -> None:
    """Append a single wallet row to the CSV."""
    pd.DataFrame([{"wallet_id": wallet_id, "wallet": wallet}]).to_csv(
        csv_path, mode="a", header=False, index=False
    )

def get_wallet_id(wallet: str, mapping: Dict[str, int], next_id_ref: List[int], csv_path: Path) -> int:
    """
    Return wallet_id for wallet, creating a new id if needed.
    next_id_ref is a single-item list to allow in-place increment.
    """
    w = str(wallet)
    wid = mapping.get(w)
    if wid is not None:
        return wid
    wid = next_id_ref[0]
    mapping[w] = wid
    next_id_ref[0] += 1
    append_wallet(csv_path, w, wid)
    return wid

# --- ETL helpers ---
def _infer_is_ask(trade: dict, idx_in_side_info: int) -> bool:
    """
    Decide if the row belongs to the ask side.
    Heuristic:
      1) If top-level 'side' is present ('A'/'B'), we tag A as asks, B as bids.
      2) Otherwise fall back to index parity inside side_info: even->A(ask), odd->B(bid).
    Adjust here if your ground truth differs.
    """
    is_ask = (idx_in_side_info % 2 == 0)  # even -> "A" (ask), odd -> "B" (bid)
    return bool(is_ask)

def retrieve_data(file_path: Path, wallet_map: Dict[str, int], next_id_ref: List[int], wallets_csv: Path = WALLETS_CSV) -> pd.DataFrame:
    """
    Read a newline-delimited JSON file of trades and produce a normalized DataFrame
    for later partitioned saving.
    Output columns: coin, price, size, time, is_ask, wallet_id
    """
    records = []
    with open(file_path) as f:
        append = records.append
        for line in f:
            if not line.strip():
                continue
            trade = json.loads(line)

            side_info_list = trade.get("side_info") or []
            for idx, side_info in enumerate(side_info_list):
                user = side_info.get("user")
                if user is None:
                    continue

                wallet_id = get_wallet_id(user, wallet_map, next_id_ref, wallets_csv)

                px = trade.get("px")
                sz = trade.get("sz")
                # skip malformed
                if px is None or sz is None:
                    continue

                append(
                    {
                        "coin": trade.get("coin"),
                        "price": float(px),
                        "size": float(sz),
                        "time": trade.get("time"),
                        "is_ask": _infer_is_ask(trade, idx),
                        "wallet_id": wallet_id,
                    }
                )

    df = pd.DataFrame.from_records(records)
    if df.empty:
        return df

    # Types & cleaning
    df["time"] = pd.to_datetime(df["time"], errors="coerce")
    df = df.dropna(subset=["time"])
    # enforce dtypes
    df["price"] = df["price"].astype("float32")
    df["size"] = df["size"].astype("float32")
    df["is_ask"] = df["is_ask"].astype("bool")
    df["wallet_id"] = df["wallet_id"].astype("uint32")

    return df[["coin", "price", "size", "time", "is_ask", "wallet_id"]]

def _target_path_for(coin: str, dt: pd.Timestamp) -> Path:
    return DATA_DIR / str(coin) / f"{dt.date()}.parquet"

def _write_daily_parquet(target: Path, df_day: pd.DataFrame) -> None:
    """
    Write/merge the daily file. If target exists, read, concat, de-dup, sort, write.
    We de-dup on [time, wallet_id, price, size, is_ask] as a reasonable row identity.
    """
    target.parent.mkdir(parents=True, exist_ok=True)

    # Keep only required columns & types
    cols = ["price", "size", "time", "is_ask", "wallet_id"]
    df_day = df_day[cols].copy()

    if target.exists():
        try:
            old = pd.read_parquet(target, engine="pyarrow")
            # Cast to same dtypes to avoid upcasting surprises
            old["price"] = old["price"].astype("float32")
            old["size"] = old["size"].astype("float32")
            old["time"] = pd.to_datetime(old["time"], errors="coerce")
            old["is_ask"] = old["is_ask"].astype("bool")
            old["wallet_id"] = old["wallet_id"].astype("uint32")
            df_day = pd.concat([old, df_day], ignore_index=True)
        except Exception as e:
            logger.warning(f"Failed to read existing parquet {target}: {e}. Overwriting.")

    df_day = df_day.dropna(subset=["time"]).drop_duplicates(
        subset=["time", "wallet_id", "price", "size", "is_ask"], keep="last"
    )
    df_day = df_day.sort_values("time")
    df_day.to_parquet(target, index=False, engine="pyarrow", compression="snappy")

def save_partitioned(df: pd.DataFrame) -> None:
    """
    Save rows to data/<coin>/<YYYY-MM-DD>.parquet, merging per-day files if present.
    """
    if df.empty:
        logger.warning("No data to save.")
        return

    # Add date for grouping
    df = df.copy()
    df["date"] = df["time"].dt.date

    # Group by coin/date
    for (coin, day), g in df.groupby(["coin", "date"], sort=False):
        if pd.isna(coin) or coin == "":
            logger.warning("Skipping rows with empty coin.")
            continue
        target = DATA_DIR / str(coin) / f"{day}.parquet"
        _write_daily_parquet(target, g)

    logger.info("Data has been saved successfully.")

# %%
old_data_folders = os.listdir(os.path.join(HOME_DIR, "hl-node-trades"))

wallet_map, next_id = load_wallet_db()
next_id_ref = [next_id]  # mutable holder


for i, date in enumerate(old_data_folders):
    hour_file_names = os.listdir(os.path.join(HOME_DIR, "hl-node-trades", date))

    for file_name in hour_file_names:
        file_full_path = os.path.join(HOME_DIR, "hl-node-trades", date, file_name)

        logger.info(f"{file_full_path} is processing")
        df = retrieve_data(Path(file_full_path), wallet_map, next_id_ref, WALLETS_CSV)
        save_partitioned(df)

    logger.info(f"Processed {i} out of {len(old_data_folders)}")
# Out:
# 2025-08-20 17:34:18.447 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250322/10.json is processing
# 2025-08-20 17:34:19.375 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:34
| INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:45:52.694 | INFO     | __main__:<module>:17 - Processed 7 out of 65
# 2025-08-20 17:45:52.695 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/10.json is processing
# 2025-08-20 17:45:54.863 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:45:54.871 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/14.json is processing
# 2025-08-20 17:45:57.244 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:45:57.248 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/12.json is processing
# 2025-08-20 17:46:00.595 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:00.605 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/0.json is processing
# 2025-08-20 17:46:04.755 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:04.771 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/4.json is processing
# 2025-08-20 17:46:07.924 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:07.931 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/8.json is processing
# 2025-08-20 17:46:11.554 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:11.563 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/13.json is processing
# 2025-08-20 17:46:15.864 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:15.877 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/3.json is processing
# 2025-08-20 17:46:19.369 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:19.375 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/2.json is processing
# 2025-08-20 17:46:23.275 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:23.283 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/6.json is processing
# 2025-08-20 17:46:26.923 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:26.928 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/1.json is processing
# 2025-08-20 17:46:31.373 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:31.384 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/7.json is processing
# 2025-08-20 17:46:35.354 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:35.360 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/5.json is processing
# 2025-08-20 17:46:39.117 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:39.122 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/9.json is processing
# 2025-08-20 17:46:43.695 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:43.703 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250525/11.json is processing
# 2025-08-20 17:46:48.280 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:48.290 | INFO     | __main__:<module>:17 - Processed 8 out of 65
# 2025-08-20 17:46:48.291 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/10.json is processing
# 2025-08-20 17:46:49.802 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:49.807 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/14.json is processing
# 2025-08-20 17:46:53.699 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:53.716 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/12.json is processing
# 2025-08-20 17:46:56.370 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:46:56.376 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/19.json is processing
# 2025-08-20 17:47:00.308 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:00.325 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/0.json is processing
# 2025-08-20 17:47:03.630 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:03.637 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/4.json is processing
# 2025-08-20 17:47:07.006 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:07.016 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/21.json is processing
# 2025-08-20 17:47:10.489 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:10.499 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/8.json is processing
# 2025-08-20 17:47:14.109 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:14.117 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/22.json is processing
# 2025-08-20 17:47:17.838 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:17.845 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/13.json is processing
# 2025-08-20 17:47:21.889 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:21.899 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/3.json is processing
# 2025-08-20 17:47:25.719 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:25.725 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/2.json is processing
# 2025-08-20 17:47:29.625 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:29.631 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/6.json is processing
# 2025-08-20 17:47:34.100 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:34.112 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/16.json is processing
# 2025-08-20 17:47:39.988 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:40.011 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/1.json is processing
# 2025-08-20 17:47:44.224 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 17:47:44.231 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250521/7.json is processing
# 2025-08-20 17:47:49.602 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# ...
# 2025-08-20 19:04:58.230 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/14.json is processing
# 2025-08-20 19:05:00.864 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:00.871 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/12.json is processing
# 2025-08-20 19:05:03.483 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:03.489 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/19.json is processing
# 2025-08-20 19:05:06.089 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:06.095 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/0.json is processing
# 2025-08-20 19:05:08.861 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:08.866 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/4.json is processing
# 2025-08-20 19:05:11.533 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:11.537 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/21.json is processing
# 2025-08-20 19:05:14.311 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:14.315 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/8.json is processing
# 2025-08-20 19:05:17.114 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:17.118 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/22.json is processing
# 2025-08-20 19:05:19.998 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:20.002 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/13.json is processing
# 2025-08-20 19:05:23.286 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:23.291 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/3.json is processing
# 2025-08-20 19:05:26.291 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:26.296 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/2.json is processing
# 2025-08-20 19:05:29.584 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:29.588 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/6.json is processing
# 2025-08-20 19:05:32.900 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:32.905 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/16.json is processing
# 2025-08-20 19:05:36.717 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:36.725 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502/1.json is processing
# 2025-08-20 19:05:40.375 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:05:40.380 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250502
| INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/6.json is processing
# 2025-08-20 19:07:48.192 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:07:48.196 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/16.json is processing
# 2025-08-20 19:07:51.018 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:07:51.021 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/1.json is processing
# 2025-08-20 19:07:53.822 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:07:53.825 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/7.json is processing
# 2025-08-20 19:07:57.064 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:07:57.068 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/20.json is processing
# 2025-08-20 19:08:00.342 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:00.347 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/5.json is processing
# 2025-08-20 19:08:03.423 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:03.426 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/9.json is processing
# 2025-08-20 19:08:06.722 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:06.726 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/11.json is processing
# 2025-08-20 19:08:10.110 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:10.115 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/18.json is processing
# 2025-08-20 19:08:13.260 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:13.263 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/15.json is processing
# 2025-08-20 19:08:16.696 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:16.700 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/17.json is processing
# 2025-08-20 19:08:20.039 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:20.042 | INFO     | __main__:<module>:13 - /home/debian/hl-node-trades/20250420/23.json is processing
# 2025-08-20 19:08:23.583 | INFO     | __main__:save_partitioned:160 - Data has been saved successfully.
# 2025-08-20 19:08:23.587 | INFO     | __main__:<module>:17 - Processed 64 out of 65

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 43.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-21.0.0

# %%
import sys

print(sys.getsizeof(20))         # int: 28
print(sys.getsizeof(3.14))      # float: 24
print(sys.getsizeof(""))        # str: 49
print(sys.getsizeof("a"))       # str: 50
print(sys.getsizeof("0x"*21))     # str: 52
# Out:
# 28
# 24
# 49
# 50
# 91
# 80

# %%
def load_wallet_db(csv_path: Path) -> Tuple[Dict[str, int], int]:
    """
    Load wallets from CSV into a dict {wallet: wallet_id}, return dict and next_id.
    If file doesn't exist, start fresh at 1.
    """
    mapping = {}
    next_id = 1
    if csv_path.exists():
        df = pd.read_csv(csv_path, dtype={"wallet_id": "uint32", "wallet": "string"})
        # handle empties gracefully
        if not df.empty:
            # ensure unique and correct mapping
            for wid, wal in zip(df["wallet_id"].astype("uint32"), df["wallet"].astype("string")):
                mapping[str(wal)] = int(wid)
            next_id = int(df["wallet_id"].max()) + 1
    else:
        # create file with header
        csv_path.parent.mkdir(parents=True, exist_ok=True)
        pd.DataFrame(columns=["wallet_id", "wallet"]).to_csv(csv_path, index=False)
    return mapping, next_id

def append_wallet(csv_path: Path, wallet: str, wallet_id: int) -> None:
    """Append a single wallet row to the CSV."""
    # minimal IO per new wallet
    pd.DataFrame(
        [{"wallet_id": wallet_id, "wallet": wallet}]
    ).to_csv(csv_path, mode="a", header=False, index=False)

def get_wallet_id(wallet: str, mapping: Dict[str, int], next_id_ref: list, csv_path: Path) -> int:
    """
    Return wallet_id for wallet, creating a new id if needed.
    next_id_ref is a single-item list to allow in-place increment.
    """
    w = str(wallet)
    wid = mapping.get(w)
    if wid is not None:
        return wid
    # assign new
    wid = next_id_ref[0]
    mapping[w] = wid
    next_id_ref[0] += 1
    append_wallet(csv_path, w, wid)
    return wid


def retrieve_data(file_path):
    records = []

    with open(file_path) as f:
        append = records.append
        for line in f:
            trade = json.loads(line)
            
            side_info_list = trade.get("side_info") or []
            for idx, side_info in enumerate(side_info_list):
                side = "A" if idx % 2 == 0 else "B"

                user = side_info.get("user")
                wallet_id = get_wallet_id(user, wallet_map, next_id_ref, WALLETS_CSV)
                
                append(
                    {
                        "coin": trade.get("coin"),
                        "price": float(trade.get("px")),
                        "size": float(trade.get("sz")),
                        "time": trade.get("time"),
                        "side": side,
                        "wallet": wallet_id,
                    }
                )

    df = pd.DataFrame.from_records(records)
    df["time"] = pd.to_datetime(df["time"], errors="coerce")
    return df


def filter_data(df, coin):
    return df[df["coin"] == coin]


def save_data(df, output_file):
    # Write to disk
    if not df.empty:
        df.to_parquet(output_file, index=False, engine='pyarrow', compression='snappy', append=os.path.exists(output_file))
        logger.info("Data has been saved successfully.")
    else:
        logger.warnning("No data to save.")

# %%
pd.read_csv(WALLETS_CSV, index_col="wallet_id")
# Out:
#                                                wallet
# wallet_id
# 1          0x31ca8395cf837de08b24da3f660e77761dfb974b
# 2          0x995f7741ab2d2d03dd1502f45e63e0adfda44dcc
# 3          0x223537ac9a856c31f4043e86ced86bb29f06653e
# 4          0x59891acadc0f8b2bcab10c043ac5fc63628b1716
# 5          0x5887de8d37c9c2550a4d0b86127c43b2e1904545
# ...                                               ...
# 9052       0xbb5048a65be6366beb86e06b21fa3018bb99340d
# 9053       0x293e5bc2a68027635a84df9966ea2f487906f5f3
# 9054       0xcb8d02079049943ea129ac10bbb51f5f9beb1128
# 9055       0x1907eeeec5f8389a6ca59f102072a3d64fa3d6e1
# 9056       0x93f1df2f8186dc9b4299791beab811b0dbf1eb50
#
# [9056 rows x 1 columns]

# %%
pd.read_parquet(DATA_DIR / "ETH" / "2025-03-22.parquet")
# Out:
#              price    size                          time  is_ask  wallet_id
# 0      1996.500000  0.0062 2025-03-22 10:50:22.049676014    True         81
# 1      1996.500000  0.0062 2025-03-22 10:50:22.049676014    True         82
# 2      1996.500000  0.0075 2025-03-22 10:50:22.049676014    True         81
# 3      1996.500000  0.0075 2025-03-22 10:50:22.049676014    True         82
# 4      1996.500000  8.0000 2025-03-22 10:50:22.049676014    True         83
# ...            ...     ...                           ...     ...        ...
# 90140  1979.599976  0.2527 2025-03-22 23:59:57.997237907    True        827
# 90141  1979.599976  1.7675 2025-03-22 23:59:57.997237907    True        826
# 90142  1979.599976  2.2007 2025-03-22 23:59:57.997237907    True         39
# 90143  1979.599976  0.0088 2025-03-22 23:59:59.328207652   False         81
# 90144  1979.599976  0.0088 2025-03-22 23:59:59.328207652   False        644
#
# [90145 rows x 5 columns]

# %%
old_data_folders = os.listdir(os.path.join(HOME_DIR, "hl-node-trades"))

wallet_map, next_id = load_wallet_db()
next_id_ref = [next_id]  # mutable holder

# %%
df_fun = retrieve_data(Path(HOME_DIR) / "hl-node-trades" / "20250322" / "10.json", wallet_map, next_id_ref, WALLETS_CSV)

# %%
file_path = Path(HOME_DIR) / "hl-node-trades" / "20250322" / "10.json"

# %%
records = []
with open(file_path) as f:
    append = records.append
    for line in f:
        trade = json.loads(line)
        
        side_info_list = trade.get("side_info")
        if len(side_info_list) != 2:
            print(len(side_info_list))
        
        for side_info, side in list(zip(side_info_list, ["A", "B"])):
            user = side_info.get("user")
            wallet_id = get_wallet_id(user, wallet_map, next_id_ref, WALLETS_CSV)
            
            append(
                {
                    "coin": trade.get("coin"),
                    "price": float(trade.get("px")),
                    "size": float(trade.get("sz")),
                    "time": trade.get("time"),
                    "side": side,
                    "wallet": wallet_id,
                }
            )

df = pd.DataFrame.from_records(records)
df["time"] = pd.to_datetime(df["time"], errors="coerce")
# return df

# %%
trade.get("side")
# Out:
# 'A'

# %%
df_fun
# Out:
#          coin        price         size                          time  is_ask  \
# 0         CRV      0.46747  4102.899902 2025-03-22 10:48:33.216798262    True
# 1         CRV      0.46747  4102.899902 2025-03-22 10:48:33.216798262   False
# 2         CRV      0.46732  2006.199951 2025-03-22 10:48:33.216798262    True
# 3         CRV      0.46732  2006.199951 2025-03-22 10:48:33.216798262   False
# 4         CRV      0.46731  4012.300049 2025-03-22 10:48:33.216798262    True
# ...       ...          ...          ...                           ...     ...
# 20683     BTC  84385.00000     0.030000 2025-03-22 10:59:59.719025144   False
# 20684  BADGER      1.69310    12.300000 2025-03-22 10:59:59.719025144    True
# 20685  BADGER      1.69310    12.300000 2025-03-22 10:59:59.719025144   False
# 20686     GAS      2.97430    13.500000 2025-03-22 10:59:59.719025144    True
# 20687     GAS      2.97430    13.500000 2025-03-22 10:59:59.719025144   False
#
#        wallet_id
# 0              1
# 1              2
# 2              3
# 3              2
# 4              4
# ...          ...
# 20683         82
# 20684         39
# 20685          1
# 20686          1
# 20687         39
#
# [20688 rows x 6 columns]

# %%
df
# Out:
#          coin        price     size                          time side  wallet
# 0         CRV      0.46747  4102.90 2025-03-22 10:48:33.216798262    A       1
# 1         CRV      0.46747  4102.90 2025-03-22 10:48:33.216798262    B       2
# 2         CRV      0.46732  2006.20 2025-03-22 10:48:33.216798262    A       3
# 3         CRV      0.46732  2006.20 2025-03-22 10:48:33.216798262    B       2
# 4         CRV      0.46731  4012.30 2025-03-22 10:48:33.216798262    A       4
# ...       ...          ...      ...                           ...  ...     ...
# 20683     BTC  84385.00000     0.03 2025-03-22 10:59:59.719025144    B      82
# 20684  BADGER      1.69310    12.30 2025-03-22 10:59:59.719025144    A      39
# 20685  BADGER      1.69310    12.30 2025-03-22 10:59:59.719025144    B       1
# 20686     GAS      2.97430    13.50 2025-03-22 10:59:59.719025144    A       1
# 20687     GAS      2.97430    13.50 2025-03-22 10:59:59.719025144    B      39
#
# [20688 rows x 6 columns]

# %%
trade
# Out:
# {'coin': 'GAS',
#  'side': 'A',
#  'time': '2025-03-22T10:59:59.719025144',
#  'px': '2.9743',
#  'sz': '13.5',
#  'hash': '0x3ff61a30b2673cef41ba04200bb69d020143002ac566845c745180be58eb56fc',
#  'trade_dir_override': 'Na',
#  'side_info': [{'user': '0x31ca8395cf837de08b24da3f660e77761dfb974b',
#    'start_pos': '-61673.4',
#    'oid': 81245875058,
#    'twap_id': None,
#    'cloid': None},
#   {'user': '0x010461c14e146ac35fe42271bdc1134ee31c703a',
#    'start_pos': '63854.8',
#    'oid': 81245877405,
#    'twap_id': None,
#    'cloid': None}]}
